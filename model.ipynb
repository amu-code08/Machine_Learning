# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# %%
with open('gingatetsudono_yoru.txt', 'r', encoding='Shift JIS') as f:
    text = f.read()

# %%
chars = sorted(list(set(text)))
vocab_size = len(chars)
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] 
decode = lambda l: ''.join([itos[i] for i in l])

# %%
# ハイパーパラメータ
batch_size = 16 # バッチサイズ
block_size = 32 # N-gramモデルのNの部分
max_iters = 6000 #学習回数
eval_interval = 100 #評価を表示する頻度
learning_rate = 1e-3 #学習率
eval_iters = 200 
n_embd = 128
n_head = 4
n_layer = 4
dropout = 0.0

# %%
# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# %%
# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    return x, y

# %%
@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# %%
class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

# %%
class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

# %%
class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# %%
# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

# %%
model = BigramLanguageModel()
# print the number of parameters in the model
print(sum(p.numel() for p in model.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long)
print(decode(model.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 1.056759 M parameters
# step 0: train loss 7.0813, val loss 7.1001
# step 100: train loss 3.8091, val loss 3.7449
# step 200: train loss 3.4289, val loss 3.4985
# step 300: train loss 3.2122, val loss 3.3669
# step 400: train loss 3.0185, val loss 3.2443
# step 500: train loss 2.8152, val loss 3.1504
# step 600: train loss 2.6132, val loss 3.0795
# step 700: train loss 2.4485, val loss 3.0487
# step 800: train loss 2.3097, val loss 3.0420
# step 900: train loss 2.1538, val loss 3.0712
# step 1000: train loss 2.0458, val loss 3.1072
# step 1100: train loss 1.9174, val loss 3.1817
# step 1200: train loss 1.7706, val loss 3.1769
# step 1300: train loss 1.6576, val loss 3.2207
# step 1400: train loss 1.5248, val loss 3.3416
# step 1500: train loss 1.4089, val loss 3.3789
# step 1600: train loss 1.2945, val loss 3.4450
# step 1700: train loss 1.2278, val loss 3.5517
# step 1800: train loss 1.1188, val loss 3.6489
# step 1900: train loss 1.0445, val loss 3.6940
# step 2000: train loss 0.9786, val loss 3.7505
# step 2100: train loss 0.9131, val loss 3.8893
# step 2200: train loss 0.8607, val loss 3.9293
# step 2300: train loss 0.8008, val loss 4.0055
# step 2400: train loss 0.7600, val loss 4.0832
# step 2500: train loss 0.7239, val loss 4.1351
# step 2600: train loss 0.6930, val loss 4.2045
# step 2700: train loss 0.6730, val loss 4.2634
# step 2800: train loss 0.6248, val loss 4.3580
# step 2900: train loss 0.6010, val loss 4.3873
# step 3000: train loss 0.5870, val loss 4.4572
# step 3100: train loss 0.5614, val loss 4.4927
# step 3200: train loss 0.5631, val loss 4.5301
# step 3300: train loss 0.5298, val loss 4.5828
# step 3400: train loss 0.5230, val loss 4.5964
# step 3500: train loss 0.5213, val loss 4.7333
# step 3600: train loss 0.5066, val loss 4.7356
# step 3700: train loss 0.5123, val loss 4.7248
# step 3800: train loss 0.4777, val loss 4.7599
# step 3900: train loss 0.4808, val loss 4.7981
# step 4000: train loss 0.4679, val loss 4.8140
# step 4100: train loss 0.4568, val loss 4.8988
# step 4200: train loss 0.4576, val loss 4.8307
# step 4300: train loss 0.4534, val loss 4.9050
# step 4400: train loss 0.4475, val loss 4.9652
# step 4500: train loss 0.4410, val loss 4.9524
# step 4600: train loss 0.4370, val loss 5.0426
# step 4700: train loss 0.4378, val loss 5.0287
# step 4800: train loss 0.4267, val loss 5.0072
# step 4900: train loss 0.4144, val loss 5.0892
# step 5000: train loss 0.4236, val loss 5.1641
# step 5100: train loss 0.4200, val loss 5.1788
# step 5200: train loss 0.4100, val loss 5.1740
# step 5300: train loss 0.4233, val loss 5.2321
# step 5400: train loss 0.4031, val loss 5.1592
# step 5500: train loss 0.4031, val loss 5.2473
# step 5600: train loss 0.3949, val loss 5.2495
# step 5700: train loss 0.4068, val loss 5.2937
# step 5800: train loss 0.4044, val loss 5.2558
# step 5900: train loss 0.3956, val loss 5.2851
# step 5999: train loss 0.3933, val loss 5.2649
#
# 「ああ、そうだ。みんながそう考える。けれどもいっしょに行けない。そしてみんながカムパネルラとわらいました。もうそして天の川がこらえから光るんだようになって、その黒い平らな頂上は、北の大熊星の下に、ぼんやりふだんだんよりも低いた出されたのだのうの野原は、まるで点くのでした。
# 　ふりかえって見分わって、そのあ屋へきまり出してうしろの両からの三だろうか」
# 　いきなり、カムパネルラが、思い切ったというように、少しどもりながら、
# 「今晩は、ごめんなさい」
# 　二人は眼を挙げ、耳をすましました。
# 「くにいや、商売ものをもらっちりしい人に送りました。
# 「ああ、十一時かっきりには帰ってます。潮を吹くとちょうど本にあるようになります」
# 「くじらなら大きいわねえ」
# 「くじら大きいです。子供だっているかぐらいのお父さんだよ」
# 　カムパネルラはにわかに窓の遠くに見えることが、二人と光って、まもなくプラットホームパネルラもいいほかのおぼしのそうでした。そしてジョバンニは青い琴の星が、三つにも四つにもなって、まっ黒にかくすきとおりるといったい何でしょう」
# 「ああ、あたしもその地図の地図の立派なことが、ちょうど両方に窓から顔を引っ込めて地図を見ていました。
# 「ああそうです。ただいちばんのさいわいに至るためにいろいろのかなしみもみんなおぼしめしです」
# 「ああ、そうだろう」カムパネルラは、白いからです。いまこそ、青い顔をして青い銀河の説なの、まだ遠くのことのものものの方とおもいないにならったって」
# 女の子がさびしそうに言いました。
# 「天、蠍がお捕りだまっ蝋をながら、もれにそのふしぎ走りました。そしてカムパネルラも、そうおまえたちの代わりにはこぐさの上にかけました。
# 「ジョバンニは、水素路が鉄砲弾いて、浮彫りのようにならんでいたのです。
# 「眼をつぶり出しているというふうにポケットに沿って出ているのでした。そこに小さな林もひびき姉弟の声をもっと聞いた小さな子どももジョバンニは高く叫び返しましたが、もうザ赤髯のなかもまた言いました。
# 「厭だい。僕もう少し汽車へ乗ってから行くんだい」
# 　青年も立ちどまって口をむすんだ。わたりこの模型をごらんなさい」
# 　先生は中にたくさん光る砂のつぶのはくをつれたように信捕り、そこらにいいんとはしをそっちを見ているのでした。
# 「きみのおっかさんは、なんにもひどいことないじゃない、行くんでしょう」腰掛けたようにまもなって遠くのもやのもやのにもしです。みなさんは夜にこの旅人が、苹果をむいきな、乳のなかに井戸がたちの幸福だとも思いました。
# 　それときどきちょうど両手をつるついていてもいきものは橙や黄いろではぼうっと青い焔のように波をあげるのでした。
# 「いいえ、氷山にぶっつかって船が沈みましてね、わたしたちはこちいんともなくないいとき、
# 「ザウエル架はすって、林のる苹果を見ました。
# 　男の子はぐったちがいま小さでもいるのでした。
# 「この地図はどこで買ったの。黒曜石でできてごらんなさい。あすこの前お父さんが持ってきて学校へ寄贈した巨きな蟹の甲らだのようなかったのだ。だから前、一つ一つの小さな平たい函をとりだして向こうの電燈のたくさんついた、たてかけてある壁の隅の所へしゃがみ込むと、小さなピンセットでまるで粟粒すなやついてでこさえたふうで、こんなこと今まで言ったよく知っていたことを祈っていていました。それはこんやの星祭りに青いあかりをこしらえて川へ行くと、おっかさんにおこって来たのです。黒曜石を河た三さをさして、ここらないのです。この模型をごらんなさい」
# 　先生は中にたくさん光る砂のつぶのはいった大きな両面の凸レンズを指しました。
# 「天の川の形はちょうどこからお話さんの自分がその少しそう言いました。
# 　二人は、停車場の前の、水晶細工のように見える銀杏の木に囲まれた、小さな広場や三角標と、おっとさんから、訊こうとして、急いで出してみついていました。
# 「ああ、そうだ、今夜ケンタウルスだよ」カムパネルラが、不思議そうに立ちどまって、岩から黒い細長いさきのとがったくるみの実のようなものをひろいました。
# 「くるみがたくさんあっておいに」
# 「いいよ」青年も立ちゃんというように光っていたのです。遠いものは小さまざまから、かすかな流れていたのです。ごらんなさい。カムパネルラはきものついた小さな星はみと手を出して、ジョバンニは、せわしくいろいろのことを考えるしげ気よく似たびたびただいい、いいいつはいいか、すきの波ばから水へ落がついて行くのでした。
# 「いいえ、どうそこは蠍がいいよ光をあげて、器気持ち油をつくしく川の微いたちにとらって、いいかおりになっていました。
# 「おまえのともでかったらあって、水は酸素と水素からできているということを知っている。けれどもだんだん焔づくな
